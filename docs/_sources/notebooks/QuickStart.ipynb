# %% [markdown]
# # Quick Start
#
# This document can tell you how to use sacpy to do Linear Regression quickly!

# %% [markdown]
# ## import useful module

# %%
# %load_ext autoreload
# %autoreload 2
import sacpy as scp 
import xarray as xr

# %% [markdown]
# ## Load Data

# %%
# load sst data
sst = scp.load_sst()['sst']
# get sst anomaly (ssta)
ssta = scp.get_anom(sst,method=0)
# plot ssta[0]
ssta[0].plot.contourf()

# %%
# get Nino3.4 Index
Nino34 = ssta.loc[:,-5:5,190:240].mean(("lon","lat"))
Nino34.plot()

# %% [markdown]
# ## Linear Regression and Plot

# %%
# Linear regression

LinReg = scp.LinReg(x=Nino34,y=ssta)
# plot the regression slope
LinReg.slope.plot.contourf(levels=15)
